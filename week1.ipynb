# %%
var1 = 3
var2 = 8

day="tuesday"

var3=23.2

# %%
var1=24
var2=15
var3=26

list_int=[1,2,4,5,6,9]
type(list_int)

list_str=["wednesday","thursday","friday"]
type(list_str)

value = list_int[0] 
print(value)

value1 = list_int[-1] 
print(value1)

list_divide= list_int[0:3]
print(list_divide)

dir(list_int)

list_int.append(7)

print(list_int)

list_int.remove(7)

print(list_int)

list_int.reverse()

print(list_int)

list_yeni=[4,2,7,1,5,3]
list_yeni.sort()

string_int_list=["onur","buber",14,11,2000]
# Out:
# 1
# 9
# [1, 2, 4]
# [1, 2, 4, 5, 6, 9, 7]
# [1, 2, 4, 5, 6, 9]
# [9, 6, 5, 4, 2, 1]

# %%
for each in range (1,11):
    print(each) 

for each in "izmir manisa":
    print(each)
   
list_1=[2,5,7,11,14,18,22,24,27,29]
sum(list_1)
    
list_2=[1,3,-21,4,-5,44,28,-90,150]  
min(list_2)  

minimum=100000

for each in list_2:
    if(each<minimum):
        minimum=each
    else:
        continue
print(minimum)

# %%
1 == 1

1 == 2

1 != 1

True == True

True == False

1>0 and 4<5

1>0 or 4<3

var1=10
var2=20

if (var1 > var2):
    print("var 1 büyüktür var 2'den")
    
elif (var1 == var2):
    print("var1 eşittir var2")
    
else :
    print("var1 küçüktür var2'den")
    

liste =[1,2,3,4,5]
value = 3

if value in liste:    
    print("value değeri {} listenin içindedir.".format(value))
    
else:
    print("value değeri {} listenin içinde değildir.".format(value))

# %%
i=0 
while (i<4):
    print(i)    
    i = i+1
# Out:
# 0
# 1
# 2
# 3

# %%
def cember_cevre(r,pi=3.14):
    output = 2*pi*r
    return output

cember_cevre(2)
# Out:
# 1
# 135

# %%
def hesapla(x):
    output= x*x    
    return output

sonuc = hesapla(3)

sonuc2 = lambda x: x*x 

print(sonuc2(3)) 

y = 3

z = lambda x:x*y

z(3) #9

# %%
dictionary = {"jason":13, "mia":32, "razor":35}

type(dictionary)

dictionary["jason"]

type(dictionary["jason"])

dictionary.keys()

dictionary.values()

def deneme():
    dictionary = {"jason":13, "mia":32, "razor":35}
    return dictionary

dic = deneme()
dic["jason"]

# %%
dictionary = {"jason":13, "mia":32, "razor":35}

keys = dictionary.keys()
if "jason" in keys:
    print("True")

else:
    print("False")
